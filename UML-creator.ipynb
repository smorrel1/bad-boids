# %%
import requests
import IPython
# import IPython
def yuml(model):
    result=requests.get("http://yuml.me/diagram/boring/class/"+model)
    return IPython.core.display.Image(result.content)

# %%
yuml("[boids|instantiate; animate]<>-behaviours*>[update_boids = boid_utilities|instantiate_boids();fly_to_middle();don't_crash();match;speed();fly_a_bit()]")
